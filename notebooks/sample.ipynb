# %% [markdown]
# ## Example 1

# %%
5+11
# Out:
# 16

# %% [markdown]
# ## Example 2

# %%
a = 1+5

# %%
a
# Out:
# 6

# %% [markdown]
# ## Example 3

# %%
from IPython import display
display.Image('https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Visual_Studio_Code_1.35_icon.svg/1920px-Visual_Studio_Code_1.35_icon.svg.png', width=200)
